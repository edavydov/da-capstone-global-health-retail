# %% [markdown]
# # Sample analysis
# This notebook demonstrates a simple data loading and summary workflow for the exemplar dataset.

# %%
import pandas as pd
print('Notebook placeholder — run analysis after loading data into DataFrame objects')

# Example: df = pd.read_csv('data/sales_sample.csv')
# df.groupby('category').agg({'revenue':'sum','order_id':'nunique'}).head()
